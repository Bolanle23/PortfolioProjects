# %% [markdown]
# ## EDA Using Supermarket_Sales dataset

# %% [markdown]
# ## Objective
# This notebook focuses on performing exploratory data analysis such as univariate analysis, bivariate analysis, and multivariate analysis
#
# ## Dataset
# The data set used is from https://www.kaggle.com/datasets/aungpyaeap/supermarket-sales

# %%
# importing Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# 1. Display Top 5 Rows of the data set
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# ## Context
# The growth of supermarkets in most populated cities are increasing and market competitions are also high. The dataset is one of the historical sales of supermarket company which has recorded in 3 different branches for 3 months data. Predictive data analytics methods are easy to apply with this dataset.
#
# ## Column information
# - Invoice id: Computer generated sales slip invoice identification number
# - Branch: Branch of supercenter (3 branches are available identified by A, B and C).
# - City: Location of supercenters
# - Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.
# - Gender: Gender type of customer
# - Product line: General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
# - Unit price: Price of each product in '$'
# - Quantity: Number of products purchased by customer
# - Tax: 5% tax fee for customer buying
# - Total: Total price including tax
# - Date: Date of purchase (Record available from January 2019 to March 2019)
# - Time: Purchase time (10am to 9pm)
# - Payment: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
# - COGS: Cost of goods sold
# - Gross margin percentage: Gross margin percentage
# - Gross income: Gross income
# - Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %%
# import the dataset
df = pd.read_csv(r"C:\Users\Bolanle\Downloads\supermarket_sales - Sheet1.csv", parse_dates=['Date'])

# %%
# 1. Display last 5 Rows of the data set
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675 2019-01-29  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900 2019-03-02  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320 2019-02-09  13:22     Cash
# 998       65.82         1   3.2910    69.1110 2019-02-22  15:33     Cash
# 999       88.34         7  30.9190   649.2990 2019-02-18  13:28     Cash
#
# ...

# %%
# Print random 5 rows
df.sample(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 630  149-61-1929      A     Yangon        Normal    Male
# 880  490-95-0021      B   Mandalay        Member  Female
# 804  831-81-6575      B   Mandalay        Member  Female
# 246  866-05-7563      B   Mandalay        Member  Female
# 196  848-24-9445      C  Naypyitaw        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 630       Sports and travel       64.19        10  32.0950  673.9950
# 880      Food and beverages       33.21        10  16.6050  348.7050
# 804  Electronic accessories       75.59         9  34.0155  714.3255
# 246  Electronic accessories       81.40         3  12.2100  256.4100
# 196       Health and beauty       43.70         2   4.3700   91.7700
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 630 2019-01-19  14:08  Credit card  641.90                 4.761905
# ...

# %%
# Find shape of the dataset
df.shape
print ("number of rows is", df.shape[0])
print ("number of columns is", df.shape[1])
# Out:
# number of rows is 1000
# number of columns is 17

# %%
# check for null values
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
# there are no null values in our dataset

# %%
# get information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %% [markdown]
# ### we convert the date column
# ### datatype to datetime dtype using: parse_dates=['Date']

# %%
# Get overall statistics about the dataset
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total  \
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749
# min      10.080000     1.000000     0.508500    10.678500
# 25%      32.875000     3.000000     5.924875   124.422375
# 50%      55.230000     5.000000    12.088000   253.848000
# 75%      77.935000     8.000000    22.445250   471.350250
# max      99.960000    10.000000    49.650000  1042.650000
# std      26.494628     2.923431    11.708825   245.885335
#
#                              Date        cogs  gross margin percentage  \
# count                        1000  1000.00000             1.000000e+03
# mean   2019-02-14 00:05:45.600000   307.58738             4.761905e+00
# min           2019-01-01 00:00:00    10.17000             4.761905e+00
# 25%           2019-01-24 00:00:00   118.49750             4.761905e+00
# 50%           2019-02-13 00:00:00   241.76000             4.761905e+00
# ...

# %%
# we want to know datatype of available columns, because numerical values 
# and categorical values are handled differently

cat=[]
num=[]
for column in df.columns:
    if df[column].nunique() > 10:
        num.append(column)
    else:
        cat.append(column)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %% [markdown]
# # Univariate Analysis
# In this analysis we focus on one column at a time and perform our analysis without considering relationship with other columns

# %% [markdown]
# # Find Aggregate Sales amonng branches. (categorical column)

# %%
# we can use countplot or barplot
sns.countplot(data = df, x='Branch')
# Out:
# <Axes: xlabel='Branch', ylabel='count'>

# %%
# we want to find the percentage of each branch using pieplot
df['Branch'].value_counts().plot(kind='pie', autopct="%1.2f%%")
plt.show()

# %% [markdown]
# #### Inference: the aggregate sales among each branches is not so different from eaach other

# %%
# we can also use barplot
df['Branch'].value_counts().plot(kind='bar')
plt.xticks(rotation= 45)
plt.show()

# %% [markdown]
# ## 2. Find the most popular payment method used by customers (categorical column)

# %%
df['Payment'].value_counts().plot(kind='bar')
plt.xticks(rotation= 45)
plt.show()

# %% [markdown]
# #### Inference: the two most popular payment methods are Ewallet and cash, having almost the same values

# %% [markdown]
# ## 3. Find the distribution of Customer Ratings. (Numerical Column)

# %%
# we can use displot or histogram
sns.displot(df['Rating'], kde=True)
plt.show()

# %%
# check the skewness of the column
df['Rating'].skew() # skewness is near to 0 this is a normal distribution
# Out:
# 0.00900964876573073

# %% [markdown]
# # 4. Find the distribution of Cost of goods sold

# %%
sns.displot(df['cogs'], kde=True)

# %%
# check the skewness of the column
df['cogs'].skew() # skewness is near to 1 this is skewed to right
# Out:
# 0.8925698049581418

# %%
# using boxplot
sns.boxplot(df['cogs'])
# Out:
# <Axes: >

# %% [markdown]
# Box plot gives 5 variable summary min, max, Q1(25th quartile),
# Q2(median), Q3(75th quartile)
#
# Interquartile range (IQR) = Q3-Q1
# This is one of the methods for outlier detection
# lower_bound = Q1 - 1.5*IQR
# upper_bound = Q3 + 1.5*IQR
# if any data point is more than upper_bound or less than lower_bound it is considered as outliers

# %% [markdown]
# # Bivariate Analysis / Multivariate Analysis
# In this analysis we analyse two or more columns to determine the relationship between them

# %% [markdown]
# # 1. Does cost of goods sold affect the ratings that the customer provide? (Numerical and numerical column)

# %%
# using scatter plot to determine the relationship between ratings and cogs
sns.scatterplot(data= df, x= 'cogs', y = 'Rating')
# Out:
# <Axes: xlabel='cogs', ylabel='Rating'>

# %% [markdown]
# #### Inference: there is no relationship between ratings and cogs

# %% [markdown]
# # 2. Does gross Income Affect the ratings that the customers provide? (Numerical and numerical column)

# %%
sns.scatterplot(data= df, x= 'gross income', y = 'Rating')
# Out:
# <Axes: xlabel='gross income', ylabel='Rating'>

# %% [markdown]
# #### Inference: there is no relationship between ratings and gross income

# %% [markdown]
# # 3. Find the most profitable branch as per gross income (numerical and categorical column)

# %%
sns.barplot(data= df, x='Branch' , y= 'gross income')
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %% [markdown]
# #### Inference: Branch C has higher income than A and B

# %%
sns.barplot(data= df, x='Branch' , y= 'gross income', hue = 'City')
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %% [markdown]
# # 4. Is there any relationship between gender and gross income?

# %%
sns.barplot(data= df, x='Gender' , y= 'gross income')
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
sns.boxplot(data= df, x='Gender' , y= 'gross income')
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
sns.boxplot(data= df, x='Gender' , y= 'gross income', hue = 'Customer type')
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %% [markdown]
# #### Inference: Female gender earn more than male gender

# %% [markdown]
# # 5. find the product line that generates most income

# %%
sns.barplot(data= df, x='Product line' , y= 'gross income')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# #### Inference: (Home and Lifestyle) and (Sports and travel) generate most income

# %% [markdown]
# # 6. Find the highest Unit Price in the product line

# %%
sns.barplot(data= df, x='Product line' , y= 'Unit price')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# # 7. find different payment method used by customers citywise

# %%
pd.crosstab(df['City'], df['Payment'])
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %%
sns.heatmap(pd.crosstab(df['City'], df['Payment']))
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %% [markdown]
# # 8. Which Product line is purchased in the highest quantity

# %%
(df.groupby('Product line')['Quantity'].sum()).plot(kind='bar')
# Out:
# <Axes: xlabel='Product line'>

# %% [markdown]
# # 9. Display Daily Sales by day of the week

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
dofweek_mapping= {0: 'Mon',
                 1: 'Tue',
                 2: 'Wed',
                 3: 'Thur',
                 4: 'Fri',
                 5: 'Sat',
                 6: 'Sun'}

# %%
df['day_of_week']=df['Date'].dt.dayofweek.map(dofweek_mapping)
df.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
#
#     Time  Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08  Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29     Cash   76.40                 4.761905        3.8200     9.6
#
#   day_of_week
# 0         Sat
# 1         Fri

# %%
df['day_of_week'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='day_of_week'>

# %% [markdown]
# # 10. What will be the highest months for sales

# %%
month_mapping = {
                1:'Jan',
                2:'Feb',
                3: 'Mar',
                4: 'Apr',
                5: 'May',
                6:'Jun',
                7:'Jul',
                8: 'Aug',
                9: 'Sep',
                10: 'Oct',
                11:'Nov',
                12: 'Dec',
               
}

# %%
df['month']=df['Date'].dt.month.map(month_mapping)
df.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
#
#     Time  Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08  Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29     Cash   76.40                 4.761905        3.8200     9.6
#
#   day_of_week month
# 0         Sat   Jan
# 1         Fri   Mar

# %%
df['month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='month'>
